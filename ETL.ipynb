# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine

# %%
UNIDAD_SIGCOM = pd.read_excel('sistema_de_alimentacion.xlsx', sheet_name='UNIDAD SIGCOM')
UNIDAD_SIGCOM
# Out:
#     IdTipoUnidad                    DescTipoUnidad Habilitado
# 0             65       HOSPITALIZACIÓN PENSIONADOS          S
# 1             66  HOSPITALIZACIÓN MEDICINA INTERNA          S
# 2             90        HOSPITALIZACIÓN QUIRÚRGICA          S
# 3            113       HOSPITALIZACIÓN OBSTETRICIA          S
# 4            114       HOSPITALIZACIÓN GINECOLOGÍA          S
# ..           ...                               ...        ...
# 56           652          SERVICIO DE ALIMENTACIÓN          S
# 57         95201              LAVANDERIA Y ROPERIA          S
# 58         95501                     MANTENIMIENTO          S
# 59           670                    ADMINISTRACIÓN          S
# 60         99544                    TRABAJO SOCIAL          S
#
# [61 rows x 3 columns]

# %%
engine = create_engine("mysql+mysqlconnector://clo87134_UserHospital:-#hfEU8*3*#G@lowedev.cl/clo87134_Hospital")

# %%
UNIDAD_SIGCOM.to_sql("TipoUnidad", engine, if_exists="replace", index=False)

# %%
SERVICIO = pd.read_excel('sistema_de_alimentacion.xlsx', sheet_name='SERVICIO')
SERVICIO
# Out:
#     IdTipoServicio                         DescTipoServicio Habilitado
# 0                0                  SIN UNIDAD - HONORARIOS          S
# 1             1104  SUB. GESTION DESARROLLO DE LAS PERSONAS          S
# 2             1108         SUBDIRECCION GESTION DEL CUIDADO          S
# 3             1109     SUBDIRECCION DE ANALISIS INFORM GEST          S
# 4             1110                DEPARTAMENTO DE AUDITORIA          S
# ..             ...                                      ...        ...
# 92            4822                  POLICLINICO GINECOLOGIA          S
# 93            4837                                 MEDICINA          S
# 94            4842                         BODEGA ECONOMATO          S
# 95            4843                          BODEGA FARMACIA          S
# 96            4849                          LISTA DE ESPERA          S
#
# [97 rows x 3 columns]

# %%
SERVICIO.to_sql("TipoServicio", engine, if_exists="replace", index=False)
# Out:
# 97

# %%
ESTAMENTO = pd.read_excel('sistema_de_alimentacion.xlsx', sheet_name='ESTAMENTO')
ESTAMENTO
# Out:
#    IdTipoEstamento DescTipoEstamento
# 0                1          AUXILIAR
# 1                2    ADMINISTRATIVO
# 2                3           TECNICO
# 3                4       PROFESIONAL
# 4                5            MEDICO
# 5                6        ODONTOLOGO
# 6                7           QUIMICO

# %%
ESTAMENTO.to_sql("TipoEstamento", engine, if_exists="replace", index=False)
# Out:
# 7

# %%
TIPO_CONTRATO = pd.read_excel('sistema_de_alimentacion.xlsx', sheet_name='TIPO CONTRATO', header=1)
TIPO_CONTRATO
# Out:
#    IdTipoContrato     TipoContrato
# 0               1          TITULAR
# 1               2         CONTRATA
# 2               3        HONORARIO
# 3               4  EMPRESA EXTERNA

# %%
TIPO_CONTRATO.to_sql("TipoContrato", engine, if_exists="replace", index=False)
# Out:
# 4

# %%
VIA = pd.read_excel('sistema_de_alimentacion.xlsx', sheet_name='VIA', header=1)
VIA
# Out:
#    IdTipoVia DescTipoVia
# 0          0        ORAL
# 1          1     ENTERAL
# 2          2  PARENTERAL

# %%
VIA.to_sql("TipoVia", engine, if_exists="replace", index=False)
# Out:
# 3

# %%
REGIMEN = pd.read_excel('sistema_de_alimentacion.xlsx', sheet_name='regimen', header=1)
REGIMEN
# Out:
#     IdTipoRegimen     DescTipoRegimen Habilitado
# 0               0               COMUN          S
# 1               1             LIVIANO          S
# 2               2             SIN SAL          S
# 3               3   DIABETICO SIN SAL          S
# 4               4   DIABETICO CON SAL          S
# 5               5  BLANDO SIN RESIDUO          S
# 6               6             LIQUIDO          S
# 7               7             HIDRICO          S
# 8               8          SIN GLUTEN          S
# 9               9              BLANCO          S
# 10             10          SOPA MIXTA          S
# 11             11             ENTERAL          S
# 12             12                CERO          S
# 13             13      CREMA DE ARROZ          S
# 14             14            ESPECIAL          S
# 15             15         VEGETARIANO          S

# %%
REGIMEN.to_sql("TipoRegimen", engine, if_exists="replace", index=False)
# Out:
# 16

# %%
FUNCIONARIOS = pd.read_excel('sistema_de_alimentacion.xlsx', sheet_name='bd funcionarios')
FUNCIONARIOS
# Out:
#           Rut Dv                Nombre Funcionario        ESTAMENTO  \
# 0    14007479  9     JORQUERA JIMENEZ NADIA KARINA  ADMINISTRATIVOS
# 1    18624405  2    BRIONES ESPINOZA HECTOR MISAEL  ADMINISTRATIVOS
# 2    14379621  3   RETAMALES PIÑA ISABEL DEL PILAR  ADMINISTRATIVOS
# 3    18777559  0          ROBLERO ROJAS JORGE LUIS  ADMINISTRATIVOS
# 4    15346159  7   RAMIREZ PALACIOS SANDRA SCARLET  ADMINISTRATIVOS
# ..        ... ..                               ...              ...
# 937  13772500  2    CORREA MENESES CAROLINA ISABEL         TECNICOS
# 938  13772563  0     GOMEZ ARMIJO ALEJANDRA ANDREA         TECNICOS
# 939  18293988  9  CURIHUAN MINIERI CRISTIAN ALONSO          MEDICOS
# 940  18293988  9  CURIHUAN MINIERI CRISTIAN ALONSO          MEDICOS
# 941  25824993  3        FARFAN ARAUJO JESUS DANIEL          MEDICOS
#
#     TIPO CONTRATO  Código Unidad        SERVICIO  Código Unidad.1  \
# 0     CONTRATADOS            NaN  ABASTECIMIENTO            670.0
# 1     CONTRATADOS            NaN  ABASTECIMIENTO            670.0
# 2     CONTRATADOS            NaN  ABASTECIMIENTO            670.0
# 3     CONTRATADOS            NaN  ABASTECIMIENTO            670.0
# 4     CONTRATADOS            NaN  ABASTECIMIENTO            670.0
# ..            ...            ...             ...              ...
# 937   CONTRATADOS            NaN             UTI              2.0
# 938     TITULARES            NaN             UTI              2.0
# 939   CONTRATADOS            NaN             UTI              2.0
# 940   CONTRATADOS            NaN             UTI              2.0
# 941   CONTRATADOS            NaN             UTI              2.0
#
#       UNIDAD SIGCOM Fecha Inicio Contrato Fecha Termino Contrato TIPO REGIMEN  \
# 0    ADMINISTRACIÓN            2023-01-01    2023-12-31 00:00:00        COMUN
# 1    ADMINISTRACIÓN            2023-01-01    2023-12-31 00:00:00        COMUN
# 2    ADMINISTRACIÓN            2023-06-01    2023-12-31 00:00:00        COMUN
# 3    ADMINISTRACIÓN            2023-06-01    2023-12-31 00:00:00        COMUN
# 4    ADMINISTRACIÓN            2023-01-01    2023-12-31 00:00:00        COMUN
# ..              ...                   ...                    ...          ...
# 937             UTI            2023-06-01    2023-12-31 00:00:00        COMUN
# 938             UTI            2018-09-01             indefinido        COMUN
# 939             UTI            2023-01-01    2023-12-31 00:00:00        COMUN
# 940             UTI            2023-01-01    2023-12-31 00:00:00        COMUN
# 941             UTI            2023-05-01    2023-12-31 00:00:00        COMUN
#
#          ESTADO
# 0    HABILITADO
# 1    HABILITADO
# 2    HABILITADO
# 3    HABILITADO
# 4    HABILITADO
# ..          ...
# 937  HABILITADO
# 938  HABILITADO
# 939  HABILITADO
# 940  HABILITADO
# 941  HABILITADO
#
# [942 rows x 13 columns]
