# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine

# %%
UNIDAD_SIGCOM = pd.read_excel('sistema_de_alimentacion.xlsx', sheet_name='UNIDAD SIGCOM')
UNIDAD_SIGCOM
# Out:
#     IdTipoUnidad                    DescTipoUnidad Habilitado
# 0             65       HOSPITALIZACIÓN PENSIONADOS          S
# 1             66  HOSPITALIZACIÓN MEDICINA INTERNA          S
# 2             90        HOSPITALIZACIÓN QUIRÚRGICA          S
# 3            113       HOSPITALIZACIÓN OBSTETRICIA          S
# 4            114       HOSPITALIZACIÓN GINECOLOGÍA          S
# ..           ...                               ...        ...
# 56           652          SERVICIO DE ALIMENTACIÓN          S
# 57         95201              LAVANDERIA Y ROPERIA          S
# 58         95501                     MANTENIMIENTO          S
# 59           670                    ADMINISTRACIÓN          S
# 60         99544                    TRABAJO SOCIAL          S
#
# [61 rows x 3 columns]

# %%
engine = create_engine("mysql+mysqlconnector://supercha_hospital:hospital123@supercharly.cl/supercha_hospital")

# %%
UNIDAD_SIGCOM.to_sql("TipoUnidad", engine, if_exists="replace", index=False)

# %%
SERVICIO = pd.read_excel('sistema_de_alimentacion.xlsx', sheet_name='SERVICIO')
SERVICIO
# Out:
#     IdTipoServicio                         DescTipoServicio Habilitado
# 0                0                  SIN UNIDAD - HONORARIOS          S
# 1             1104  SUB. GESTION DESARROLLO DE LAS PERSONAS          S
# 2             1108         SUBDIRECCION GESTION DEL CUIDADO          S
# 3             1109     SUBDIRECCION DE ANALISIS INFORM GEST          S
# 4             1110                DEPARTAMENTO DE AUDITORIA          S
# ..             ...                                      ...        ...
# 92            4822                  POLICLINICO GINECOLOGIA          S
# 93            4837                                 MEDICINA          S
# 94            4842                         BODEGA ECONOMATO          S
# 95            4843                          BODEGA FARMACIA          S
# 96            4849                          LISTA DE ESPERA          S
#
# [97 rows x 3 columns]

# %%
SERVICIO.to_sql("TipoServicio", engine, if_exists="replace", index=False)
# Out:
# 97

# %%
ESTAMENTO = pd.read_excel('sistema_de_alimentacion.xlsx', sheet_name='ESTAMENTO')
ESTAMENTO
# Out:
#    IdTipoEstamento DescTipoEstamento
# 0                1          AUXILIAR
# 1                2    ADMINISTRATIVO
# 2                3           TECNICO
# 3                4       PROFESIONAL
# 4                5            MEDICO
# 5                6        ODONTOLOGO
# 6                7           QUIMICO
# 7                8         DIRECTIVO

# %%
ESTAMENTO.to_sql("TipoEstamento", engine, if_exists="replace", index=False)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\mysql\connector\connection_cext.py:608, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     607         query = query.encode("utf-8")
# --> 608     self._cmysql.query(
#     609         query,
#     610         raw=raw,
#     611         buffered=buffered,
#     612         raw_as_string=raw_as_string,
#     613         query_attrs=self._query_attrs,
#     614     )
#     615 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Cannot delete or update a parent row: a foreign key constraint fails
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# ...

# %%
TIPO_CONTRATO = pd.read_excel('sistema_de_alimentacion.xlsx', sheet_name='TIPO CONTRATO', header=1)
TIPO_CONTRATO
# Out:
#    IdTipoContrato                   TipoContrato
# 0               1                        TITULAR
# 1               2                       CONTRATA
# 2               3                      HONORARIO
# 3               4                EMPRESA EXTERNA
# 4               5                       SUPLENTE
# 5               6  ETAPA DESTINACIÓN Y FORMACIÓN

# %%
TIPO_CONTRATO.to_sql("TipoContrato", engine, if_exists="replace", index=False)
# Out:
# 4

# %%
VIA = pd.read_excel('sistema_de_alimentacion.xlsx', sheet_name='VIA', header=1)
VIA
# Out:
#    IdTipoVia DescTipoVia
# 0          0        ORAL
# 1          1     ENTERAL
# 2          2  PARENTERAL

# %%
VIA.to_sql("TipoVia", engine, if_exists="replace", index=False)
# Out:
# 3

# %%
REGIMEN = pd.read_excel('sistema_de_alimentacion.xlsx', sheet_name='regimen', header=1)
REGIMEN
# Out:
#     IdTipoRegimen     DescTipoRegimen Habilitado
# 0               0               COMUN          S
# 1               1             LIVIANO          S
# 2               2             SIN SAL          S
# 3               3   DIABETICO SIN SAL          S
# 4               4   DIABETICO CON SAL          S
# 5               5  BLANDO SIN RESIDUO          S
# 6               6             LIQUIDO          S
# 7               7             HIDRICO          S
# 8               8          SIN GLUTEN          S
# 9               9              BLANCO          S
# 10             10          SOPA MIXTA          S
# 11             11             ENTERAL          S
# 12             12                CERO          S
# 13             13      CREMA DE ARROZ          S
# 14             14            ESPECIAL          S
# 15             15         VEGETARIANO          S

# %%
FUNCIONARIOS.to_sql("TipoRegimen", engine, if_exists="replace", index=False)
# Out:
# 16

# %%
FUNCIONARIOS = pd.read_excel('sistema_de_alimentacion.xlsx', sheet_name='funcionarios')

# %%
FUNCIONARIOS.sample(20)
# Out:
#      RutFuncionario DvFuncionario                          NombreFuncionario
# 135        13843785             K                   PEREZ AEDO JAMIE ZULEYKA  \
# 590        15511304             9              ROJAS MENESES MARICELA CARMEN
# 127        12178307             K                   GODOY SILVA JORGE MANUEL
# 274        10179897             6                  ARAOS ARMIJO SANDRA MARIA
# 12         18761767             7                ASTORGA PIÑA BELEN CAROLINA
# 546        20124742             K             PINTO GONZALEZ KATHERINE PILAR
# 559        18213059             1          ALMARZA ESQUIVEL ANDREA DEL PILAR
# 207        25783754             8                 PLAZA MEJIA ELVIS MAURICIO
# 388        17397506             6          CACERES GUERRERO VANESA DEL PILAR
# 729        16297678             8                   MUÑOZ ARAYA KAREN LORENA
# 746        10334468             9       RAMIREZ QUINTEROS ALEJANDRA DEYANIRA
# ...

# %%
FUNCIONARIOS.columns = FUNCIONARIOS.columns.str.replace('\xa0', '')

# %%
FUNCIONARIOS['IdTipoFuncionario'] = pd.to_numeric(FUNCIONARIOS['IdTipoFuncionario'], errors='coerce').fillna(0).astype(int)
FUNCIONARIOS['IdTipoUnidad'] = pd.to_numeric(FUNCIONARIOS['IdTipoUnidad'], errors='coerce').fillna(10000).astype(int)

# %%
FUNCIONARIOS['correo'] = FUNCIONARIOS['correo'].astype(object)
FUNCIONARIOS['contrasena'] = FUNCIONARIOS['contrasena'].astype(object)

# %%
FUNCIONARIOS.to_sql("Funcionario", engine, if_exists="replace", index=False)
# Out:
# 857
